# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
data = pd.read_csv("datos_limpios.csv")
df = pd.read_csv("Datos_Antioquia.csv")

# %% [markdown]
# df es el dataframe con todas las variables

# %%
df.describe()
# Out:
#              periodo  cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# count  153196.000000                   1.531960e+05        1.531960e+05
# mean    20194.148072                   1.742534e+11        1.748716e+11
# std         2.904329                   9.047691e+10        9.044255e+10
# min     20181.000000                   1.050010e+11        1.050010e+11
# 25%     20194.000000                   1.050450e+11        1.050450e+11
# 50%     20194.000000                   1.056070e+11        1.056150e+11
# 75%     20194.000000                   3.050010e+11        3.050010e+11
# max     20221.000000                   4.058730e+11        4.058870e+11
#
#        cole_cod_depto_ubicacion  cole_cod_mcpio_ubicacion  cole_codigo_icfes  \
# count                  153196.0             153196.000000      153196.000000
# mean                        5.0               5225.047064      225714.337555
# std                         0.0                275.178943      249720.533419
# min                         5.0               5001.000000          75.000000
# 25%                         5.0               5001.000000       50898.000000
# 50%                         5.0               5088.000000      131136.000000
# 75%                         5.0               5368.000000      208017.000000
# max                         5.0               5895.000000      779199.000000
#
#        estu_cod_depto_presentacion  estu_cod_mcpio_presentacion  \
# count                153196.000000                153196.000000
# mean                      5.185423                  5401.139109
# std                       3.059874                  3066.673866
# min                       5.000000                  5001.000000
# 25%                       5.000000                  5001.000000
# 50%                       5.000000                  5088.000000
# 75%                       5.000000                  5360.000000
# max                      76.000000                 76892.000000
#
#        estu_cod_reside_depto  estu_cod_reside_mcpio    punt_ingles  \
# count          153126.000000          153126.000000  153192.000000
# mean                5.046491            5269.650419      48.178599
# std                 1.366324            1392.844648      14.091804
# min                 5.000000            5001.000000       0.000000
# 25%                 5.000000            5001.000000      38.000000
# 50%                 5.000000            5088.000000      47.000000
# 75%                 5.000000            5361.000000      57.000000
# max                91.000000           91460.000000     100.000000
#
#        punt_matematicas  punt_sociales_ciudadanas  punt_c_naturales  \
# count     153196.000000             153196.000000     153196.000000
# mean          49.493897                 46.253447         46.929835
# std           12.477493                 12.439265         11.097268
# min            0.000000                  0.000000          0.000000
# 25%           40.000000                 36.000000         38.000000
# 50%           49.000000                 45.000000         46.000000
# 75%           58.000000                 55.000000         55.000000
# max          100.000000                100.000000        100.000000
#
#        punt_lectura_critica    punt_global
# count         153196.000000  153196.000000
# mean              52.339219     243.548506
# std               10.816328      53.267423
# min                0.000000      14.000000
# 25%               45.000000     202.000000
# 50%               53.000000     240.000000
# 75%               60.000000     281.000000
# max              100.000000     473.000000

# %% [markdown]
# Data es el dataframe que contiene SOLO las variables a utilizar en el modelo

# %%
data.describe()
# Out:
#        cole_area_ubicacion  cole_bilingue  cole_caracter  \
# count         60023.000000   60023.000000   60023.000000
# mean              0.144245       0.016560       0.511770
# std               0.351341       0.127618       0.587223
# min               0.000000       0.000000      -1.000000
# 25%               0.000000       0.000000       0.000000
# 50%               0.000000       0.000000       0.000000
# 75%               0.000000       0.000000       1.000000
# max               1.000000       1.000000       2.000000
#
#        cole_cod_mcpio_ubicacion   cole_genero  cole_jornada  cole_naturaleza  \
# count              60023.000000  60023.000000  60023.000000     60023.000000
# mean                5219.182763      0.055845      2.177415         0.244473
# std                  272.404141      0.251244      1.503695         0.429778
# min                 5001.000000      0.000000      0.000000         0.000000
# 25%                 5001.000000      0.000000      1.000000         0.000000
# 50%                 5088.000000      0.000000      2.000000         0.000000
# 75%                 5361.000000      0.000000      3.000000         0.000000
# max                 5895.000000      2.000000      5.000000         1.000000
#
#        cole_sede_principal   estu_genero  estu_fechanacimiento  ...  \
# count         60023.000000  60023.000000          60023.000000  ...
# mean              0.973627      0.559652           1996.121487  ...
# std               0.160244      0.496433             97.501684  ...
# min               0.000000      0.000000              1.000000  ...
# 25%               1.000000      0.000000           2001.000000  ...
# 50%               1.000000      1.000000           2002.000000  ...
# 75%               1.000000      1.000000           2002.000000  ...
# max               1.000000      1.000000           2020.000000  ...
#
#        fami_cuartoshogar  fami_educacionmadre  fami_educacionpadre  \
# count        60023.00000         60023.000000         60023.000000
# mean             2.80919             2.357696             1.957133
# std              1.01475             2.414201             2.532205
# min              1.00000            -3.000000            -3.000000
# 25%              2.00000             0.000000             0.000000
# 50%              3.00000             2.000000             2.000000
# 75%              3.00000             4.000000             3.000000
# max              7.00000             8.000000             8.000000
#
#        fami_estratovivienda  fami_personashogar  fami_tieneautomovil  \
# count          60023.000000        60023.000000         60023.000000
# mean               2.333739            4.346392             0.239625
# std                1.166195            1.475671             0.426858
# min                0.000000            2.500000             0.000000
# 25%                2.000000            3.500000             0.000000
# 50%                2.000000            3.500000             0.000000
# 75%                3.000000            5.500000             0.000000
# max                6.000000            9.000000             1.000000
#
#        fami_tienecomputador  fami_tieneinternet  fami_tienelavadora  \
# count          60023.000000        60023.000000        60023.000000
# mean               0.632674            0.720957            0.832381
# std                0.482080            0.448532            0.373531
# min                0.000000            0.000000            0.000000
# 25%                0.000000            0.000000            1.000000
# 50%                1.000000            1.000000            1.000000
# 75%                1.000000            1.000000            1.000000
# max                1.000000            1.000000            1.000000
#
#         punt_global
# count  60023.000000
# mean     248.185829
# std       53.252104
# min      100.000000
# 25%      207.000000
# 50%      245.000000
# 75%      286.000000
# max      473.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Análisis de los aspectos socioeconómicos

# %% [markdown]
# Entonces, las personas cuyos inmuebles pertenezcan a los estratos 1, 2 o 3 significaría que se ubican en la clasificación más baja y en los estratos 5 y 6 se localizan las personas con mayores ingresos económicos (Restrepo, 2024)

# %%
estu_fam_bajo = data[
    (data["fami_estratovivienda"].isin([1, 2, 3])) & 
    (data["fami_tienecomputador"] == 0) & 
    (data["fami_tieneinternet"] == 0)
]
estu_fam_medio = data[
    (data["fami_estratovivienda"] == 4) & 
    (data["fami_tienecomputador"] == 1) & 
    (data["fami_tieneinternet"] == 1)
]
estu_fam_alto = data[
    (data["fami_estratovivienda"].isin([5,6])) & 
    (data["fami_tienecomputador"] == 1) & 
    (data["fami_tieneinternet"] == 1)
]

# %%
plt.figure(figsize=(14, 8))
sns.histplot(estu_fam_bajo['punt_global'], color='blue', label='Bajo', kde=True, stat="density")
sns.histplot(estu_fam_medio['punt_global'], color='green', label='Medio', kde=True, stat="density")
sns.histplot(estu_fam_alto['punt_global'], color='red', label='Alto', kde=True, stat="density")
plt.title('Distribución de punt_global por nivel socioeconómico')
plt.xlabel('punt_global')
plt.ylabel('Densidad')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
dataframes = [estu_fam_bajo.assign(Nivel='Bajo'), estu_fam_medio.assign(Nivel='Medio'), estu_fam_alto.assign(Nivel='Alto')]
combined_df = pd.concat(dataframes)
sns.boxplot(x='Nivel', y='punt_global', data=combined_df,color="pink")
plt.title('Boxplot de punt_global por nivel socioeconómico')
plt.xlabel('Nivel Socioeconómico')
plt.ylabel('punt_global')
plt.show()

# %%
palette = sns.color_palette("Set2")
plt.figure(figsize=(12, 6))
sns.countplot(x='cole_naturaleza', hue='Nivel', data=combined_df,palette=palette)
plt.title('Distribución de cole_naturaleza por nivel socioeconómico')
plt.xlabel('Naturaleza del colegio   0: No oficial  1: Oficial')
plt.ylabel('Cuenta')
plt.legend(title='Nivel Socioeconómico')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\57051424.py:3: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.countplot(x='cole_naturaleza', hue='Nivel', data=combined_df,palette=palette)

# %% [markdown]
# ### Análisis de los puntajes

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
df[['punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica',"punt_ingles", 'punt_global']].hist(bins=30, edgecolor='black', layout=(2, 3), figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
import seaborn as sns
sns.boxplot(data=df[["punt_ingles",'punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica']])
plt.title('Box plots de puntajes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df[["punt_ingles",'punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica']])
plt.title('Violin plots de puntajes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.pairplot(df[["punt_ingles",'punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica']])
plt.suptitle('Scatter plots entre puntajes', y=1.02)
plt.show()

# %%
# Matriz de correlación --> Variables numéricas de puntajes de las competencias
corr = df[["punt_ingles",'punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Matriz de correlación entre puntajes')
plt.show()

# %% [markdown]
# ### Comparación entre colegios bilingues y colegios no bilingues

# %%
df['cole_bilingue_desc'] = df['cole_bilingue'].map({'S': 'Colegio Bilingüe', 'N': 'Colegio NO Bilingüe'})
bilingual = df[df['cole_bilingue'] == 'S']
non_bilingual = df[df['cole_bilingue'] == 'N']

# %%
palette = sns.color_palette("Set2")

# Box plots comparativos
plt.figure(figsize=(15, 8))
for i, col in enumerate(['punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica', 'punt_global']):
    plt.subplot(2, 3, i+1)
    sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
    plt.title(f'Comparación de {col}')
    #plt.grid(True)
plt.tight_layout()
plt.show()

# Violin plots comparativos
plt.figure(figsize=(15, 8))
for i, col in enumerate(['punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica', 'punt_global']):
    plt.subplot(2, 3, i+1)
    sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
    plt.title(f'Comparación de {col}')
    #plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:7: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.boxplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7672\2976293113.py:17: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.violinplot(x='cole_bilingue_desc', y=col, data=df, palette=palette)

# %% [markdown]
# Prueba de diferencia de medias

# %%
means = df.groupby('cole_bilingue_desc')[['punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica', 'punt_global']].mean()
means.plot(kind='bar', figsize=(10, 6), color=palette)
plt.title('Comparación de medias de puntajes')
plt.ylabel('Puntaje promedio')
plt.xticks(rotation=0)
plt.legend(title='Puntajes')
plt.grid(True)
plt.show()

# %%
from scipy.stats import ttest_ind
####--------------
#Prueba t para las diferencias de medias
# HO: u1 = u2 --> u1 - u2 = 0
# H1: u1 != u2 --> u1 - u2 != 0
####--------------
for col in ['punt_matematicas', 'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica', 'punt_global']:
    t_stat, p_val = ttest_ind(bilingual[col], non_bilingual[col], equal_var=False)
    print(f'Test t para {col}: estadístico t = {t_stat:.2f}, p-value = {p_val:.4f}')
# Out:
# Test t para punt_matematicas: estadístico t = 30.97, p-value = 0.0000
# Test t para punt_sociales_ciudadanas: estadístico t = 28.26, p-value = 0.0000
# Test t para punt_c_naturales: estadístico t = 30.50, p-value = 0.0000
# Test t para punt_lectura_critica: estadístico t = 26.56, p-value = 0.0000
# Test t para punt_global: estadístico t = 34.08, p-value = 0.0000
